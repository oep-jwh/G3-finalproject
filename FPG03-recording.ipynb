# %% [markdown]
# <a href="https://colab.research.google.com/github/bori0824/G3-finalproject/blob/main/FPG03-recording.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌱**Group 3 Final Project (6/18)**
#
# + Reading material: 💾 [text link](https://raw.githubusercontent.com/MK316/Spring2024/main/DLTESOL/project/story03.txt)
#
# ## Learning objectives:
# + objective 1:
# + objective 1:
# + objective 1:

# %%
# !pip install pydub
# !pip install ffmpeg-python

# %%
from IPython.display import display, HTML, Javascript

def record_audio():
    display(HTML("""
    <script>
        var my_recorder;
        var audioChunks = [];

        function startRecording() {
            navigator.mediaDevices.getUserMedia({ audio: true }).then(stream => {
                my_recorder = new MediaRecorder(stream);
                my_recorder.ondataavailable = function(event) {
                    audioChunks.push(event.data);
                };
                my_recorder.start();
            });
        }

        function stopRecording() {
            my_recorder.stop();
            my_recorder.onstop = function() {
                var audioBlob = new Blob(audioChunks, { type: 'audio/wav' });
                var audioUrl = URL.createObjectURL(audioBlob);
                var audio = new Audio(audioUrl);
                var anchor = document.createElement("a");
                anchor.href = audioUrl;
                anchor.download = "recorded_audio.wav";
                anchor.click();
                audio.play();
            };
        }
    </script>
    <button onclick="startRecording()">Start Recording</button>
    <button onclick="stopRecording()">Stop Recording</button>
    """))

record_audio()
